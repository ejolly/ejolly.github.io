# %% [markdown]
# # Title

# %%
from __future__ import division
import numpy as np
import pandas as pd
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
import nibabel as nib
import cPickle as pickle
from nltools.data import Brain_Data
from nltools.mask import expand_mask, collapse_mask
from scipy.stats import pearsonr, spearmanr
from scipy.spatial.distance import pdist, squareform
from copy import copy, deepcopy
#http://nipy.org/nipy/api/generated/nipy.modalities.fmri.hemodynamic_models.html
from nipy.modalities.fmri.hemodynamic_models import glover_hrf, spm_hrf
from collections import OrderedDict as od
plt.style.use(['EshFonts']) #change default font sizes 
# %matplotlib inline

# %% [markdown]
# ## Sub title

# %%
allSubs = Brain_Data()
for elem in subPredictions:
    allSubs = allSubs.append(elem['weight_map'])

# %%
allSubs
# Out:
# nltools.data.Brain_Data(data=(13, 238955), Y=0, X=(0, 0), mask=MNI152_T1_2mm_brain_mask.nii.gz, output_file=[])

# %% [markdown]
# ### Something else

# %% [markdown]
# This is a list:
# - what
# - the
# - hell

# %%
plotTBrain(allSubs,alpha=.01)
